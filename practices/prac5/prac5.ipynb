# %%
try:
    import google.colab
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB = True
except:
    COLAB = False

# !pip install gymnasium==0.29.1 vizdoom==1.2.4 wandb==0.19.1
# Out:
# Mounted at /content/drive
# Collecting gymnasium==0.29.1
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Collecting vizdoom==1.2.4
#   Downloading vizdoom-1.2.4-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (11 kB)
# Collecting wandb==0.19.1
#   Downloading wandb-0.19.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.29.1) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.29.1) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.29.1) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.29.1) (0.0.4)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from vizdoom==1.2.4) (2.6.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (8.3.0)
# Collecting docker-pycreds>=0.4.0 (from wandb==0.19.1)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (4.5.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (5.29.5)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (5.9.5)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (2.11.10)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (2.32.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (2.42.1)
# Collecting setproctitle (from wandb==0.19.1)
#   Downloading setproctitle-1.3.7-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (75.2.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from docker-pycreds>=0.4.0->wandb==0.19.1) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb==0.19.1) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb==0.19.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb==0.19.1) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb==0.19.1) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.19.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.19.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.19.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.19.1) (2025.10.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb==0.19.1) (5.0.2)
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 48.1 MB/s eta 0:00:00
# Downloading vizdoom-1.2.4-cp312-cp312-manylinux_2_28_x86_64.whl (28.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.1/28.1 MB 42.7 MB/s eta 0:00:00
# Downloading wandb-0.19.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 16.2 MB/s eta 0:00:00
# Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Downloading setproctitle-1.3.7-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (32 kB)
# Installing collected packages: setproctitle, gymnasium, docker-pycreds, vizdoom, wandb
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.2.1
#     Uninstalling gymnasium-1.2.1:
#       Successfully uninstalled gymnasium-1.2.1
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.22.2
#     Uninstalling wandb-0.22.2:
#       Successfully uninstalled wandb-0.22.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.1 which is incompatible.
# Successfully installed docker-pycreds-0.4.0 gymnasium-0.29.1 setproctitle-1.3.7 vizdoom-1.2.4 wandb-0.19.1

# %%
import json
import math
import random
import sys
import os
import time
from collections import deque
from typing import Dict, Type, Any, Tuple, NamedTuple, Optional, Union, Generator, List

import gymnasium as gym
import gymnasium.spaces as spaces
from gymnasium.vector import AsyncVectorEnv, SyncVectorEnv
from gymnasium.wrappers import ResizeObservation, GrayScaleObservation, RecordEpisodeStatistics, TransformReward, \
    FrameStack
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn.functional as F
from torch import nn
from torch.distributions import Categorical
import vizdoom
from vizdoom import gymnasium_wrapper

try:
    import wandb
    WANDB_IS_AVAILABLE = True
except ImportError:
    WANDB_IS_AVAILABLE = False

os.environ["WANDB_API_KEY"] = "e97ffa4c776cbfb2c0fc0c8b5c97e875139c1d42"

# %% [markdown]
# # Градиент стратегии: REINFORCE
#
# Обозначения:
# - $s$ - состояние, $r$ - вознаграждение, $a$ - действие
# - Условное распределение действий $\pi(a | s)$ - стратегия агента
# - $\tau$ - траектория: $(s_0, r_0, a_0), \dots, (s_T, r_T, a_T)$
# - Отдача $G(\tau) = \sum_{t = 0} ^ T r_t \gamma ^ t$
# - $G_t = r_t + r_{t + 1} \gamma + \dots + r_{T} \gamma ^ {T - t}$
# - Функция полезности состояний: $V(s_{t}) = \mathbb{E}[G_t]$
# - Функция полезности действий: $Q(s_t, a_t) = \mathbb{E}[r_t + \gamma V(s_{t + 1}) | a_t]$
#
# В некоторых задачах для нахождения удовлетворительной стратегии необязательно в точности знать структуру всей среды. Например, в задаче поднятия кубика робототехнической рукой вместо точной аппроксимации полезности $Q(s,a)$ достаточно знать, что выгоднее: двигаться вправо, если кубик справа, и влево в ином случае. С этим же наблюдением связано и предположение, что задача поиска удовлетворительной стратегии проще, нежели задача точной оценки функции полезности.
#
# В данном семинаре познакомимся с простейшим методом прямой оптимизации стратегии REINFORCE, в котором параметры, задающие вероятностную стратегию, изменяются в соответствии с градиентом математического ожидания отдач:
#
# $$J(\theta)= \mathbb{E}[G(\tau)],$$
#
# $$\theta \leftarrow \theta +\alpha \nabla_{\theta} J(\theta),$$
#
# В первом выражении математическое ожидание берется по распределениям начальных состояний, вероятностным функциям переходов и вознаграждений среды, а также по вероятностной стратегии агента $\pi_\theta$. Благодаря теореме о существовании стационарного распределения марковской цепи, это выражение может быть переписано через стационарное распределение $d^\pi$ посещения состояний в среде:
#
# $$J(\theta)= \mathbb{E}_{s \sim d^\pi}[V^{\pi}(s)] = \mathbb{E}_{s \sim d^\pi, a \sim \pi(s)} [Q^{\pi}(s, a)] =: \mathbb{E}_\pi [Q^{\pi}(s, a)].$$
#
# Метод REINFORCE также использует теорему о градиенте стратегии, на основе которой построено целое семейство алгоритмов прямой оптимизации стратегии и актор-критиков. Теорема о градиенте стратегии связывает градиент целевой функции $J$ и градиент самой стратегии:
#
# $$\nabla_\theta J(\theta) = \mathbb{E}_\pi [Q^\pi(s, a) \nabla_\theta \ln \pi_\theta(a \vert s)]$$
#
# Для оценки полезности действий $Q^\pi(s, a)$ REINFORCE использует несмещенную Монте-Карло оценку на основе полученных в среде отдач $G_t$ (за некоторое фиксированное число эпизодов в среде). С учетом этого обновление весов осуществляется по правилу:
#
# $$\nabla_\theta J(\theta) = \mathbb{E}_\pi [G_t \nabla_\theta \ln \pi_\theta(a_t \vert s_t)]$$
#
# Более подробное (но все равно короткое) описание градиента стратегии, и в частности REINFORCE, можно посмотреть в [блоге Lilian Weng из OpenAI](https://lilianweng.github.io/posts/2018-04-08-policy-gradient/#policy-gradient), либо полноценно разобраться в соответствующей секции классического учебника Саттона и Барто.

# %% [markdown]
# ### Environment: Vizdoom
# Среда для экспериментов: **Vizdoom**. Задача: **VizdoomCorridor-v0**.
#
# Карта представляет собой коридор со стреляющими противниками по обеим сторонам. Зелёная броня размещена на противоположном конце коридора. Цель агента — добраться до предмета. Награда пропорциональна (отрицательна или положительна) изменению расстояния между игроком и жилетом.
# - Вознаграждение: +dX за приближение к броне, -dX за отдаление от брони, -100 за смерть.
# - Агенту доступны 7 действий: движение вперед/назад/влево/вправо, поворот влево/вправо, стрельба.
# - Ограничение по времени: 2100 шагов
#
# Для ускорения обучения агента рассматриваем самый простой уровень сложности `doom_skill = 1`.

# %%
def create_vizdoom_config(verbose=False):
    # Создаёт файл сценария VizdoomCorridor с уровнем сложности doom_skill = 1

    deadly_corridor_doom_skill_1 = """
    # Lines starting with # are treated as comments (or with whitespaces+#).
    # It doesn't matter if you use capital letters or not.
    # It doesn't matter if you use underscore or camel notation for keys, e.g. episode_timeout is the same as episodeTimeout.
    """
    deadly_corridor_doom_skill_1 += f"\ndoom_scenario_path = {os.path.relpath(os.path.dirname(vizdoom.__file__))}/scenarios/deadly_corridor.wad\n"
    deadly_corridor_doom_skill_1 += """
    # Skill 5 is recommended for the scenario to be a challenge.
    doom_skill = 1

    # Rewards
    death_penalty = 100
    #living_reward = 0

    # Rendering options
    screen_resolution = RES_320X240
    screen_format = CRCGCB
    render_hud = true
    render_crosshair = false
    render_weapon = true
    render_decals = false
    render_particles = false
    window_visible = true

    episode_timeout = 2100

    # Available buttons
    available_buttons =
      {
        MOVE_LEFT
        MOVE_RIGHT
        ATTACK
        MOVE_FORWARD
        MOVE_BACKWARD
        TURN_LEFT
        TURN_RIGHT
      }

    # Game variables that will be in the state
    available_game_variables = { HEALTH }

    mode = PLAYER
    """

    config_file_name = f'deadly_corridor_doom-skill-1.cfg'
    with open(config_file_name, 'w') as file_obj:
        print(deadly_corridor_doom_skill_1, file=file_obj)

    if verbose:
        print(deadly_corridor_doom_skill_1)

    return os.path.realpath(config_file_name)


def source_env_info():
    config_file_path = create_vizdoom_config()
    env = gym.make('VizdoomCorridor-v0', **{'scenario_file': config_file_path})
    obs, _ = env.reset()
    plt.imshow(obs['screen'])
    plt.show()
    print(env.env.env.spec.kwargs)

source_env_info()
# Out:
# /usr/local/lib/python3.12/dist-packages/vizdoom/gymnasium_wrapper/base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# {'scenario_file': '/content/deadly_corridor_doom-skill-1.cfg'}

# %% [markdown]
# ### Wrappers

# %%
class ImageExtractorWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
        self.observation_space = env.observation_space['screen']

    def observation(self, observation: Dict) -> np.ndarray:
        return observation['screen']


def make_env():
    config_file_path = create_vizdoom_config()
    env = gym.make('VizdoomCorridor-v0', **{'scenario_file': config_file_path})
    env = ImageExtractorWrapper(env)
    env = GrayScaleObservation(env)
    env = ResizeObservation(env, shape=84)
    env = FrameStack(env, num_stack=3)
    env = RecordEpisodeStatistics(env)
    env = TransformReward(env, f=lambda reward: reward / 100.)

    return env


def wrapped_env_info():
    config_file_path = create_vizdoom_config()
    env = make_env()
    env.reset()
    terminated = False
    while not terminated:
        obs, reward, terminated, truncated, info = env.step(env.action_space.sample())

    fig, axes = plt.subplots(1, 3, figsize=(12, 3))
    for ax, frame in zip(axes, obs):
        ax.imshow(frame, cmap='gray')

    print('Наблюдение - стек из 3х последовательных изображений 84х84 в оттенках серого, shape:', obs.shape)
    plt.show()
    print('info на последнем шаге содержит статистику эпизода: r - суммарное вознаграждение, l - длина эпизода, t - продолжительность эпизода в секундах\n', info)

DEMO_WRAPPED_ENV = True
if DEMO_WRAPPED_ENV:
    wrapped_env_info()
# Out:
# Наблюдение - стек из 3х последовательных изображений 84х84 в оттенках серого, shape: (3, 84, 84)
# info на последнем шаге содержит статистику эпизода: r - суммарное вознаграждение, l - длина эпизода, t - продолжительность эпизода в секундах
#  {'episode': {'r': array([-106.70114], dtype=float32), 'l': array([468], dtype=int32), 't': array([0.768555], dtype=float32)}}

# %% [markdown]
# ### Misc

# %%
def set_seed_everywhere(seed: int, using_cuda: bool = False) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    if using_cuda:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

# %% [markdown]
# # 1 REINFORCE

# %% [markdown]
# ### Policy
# Основные компоненты ReinforcePolicy:
# - `features_extractor` - свёрточный энкодер, кодирующий изображения в латентный вектор
# - `action_net` - полносвязный слой, который выдаёт логиты действий для предсказания вероятностей

# %% [markdown]
# ![policy](data:image/png;base64,...)

# %%
class Encoder(nn.Module):
    def __init__(
            self,
            observation_space: gym.Space,
            features_dim: int = 512,
    ) -> None:
        super().__init__()
        self.features_dim = features_dim
        n_input_channels = observation_space.shape[0]
        self.cnn = nn.Sequential(
            nn.Conv2d(n_input_channels, 32, kernel_size=8, stride=4, padding=0),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=0),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=0),
            nn.ReLU(),
            nn.Flatten(),
        )

        with torch.no_grad():
            n_flatten = self.cnn(torch.as_tensor(observation_space.sample()[None]).float()).shape[1]

        self.linear = nn.Sequential(nn.Linear(n_flatten, features_dim), nn.ReLU())

    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        return self.linear(self.cnn(observations))


class ReinforcePolicy(nn.Module):
    def __init__(self, observation_space: gym.Space, action_space: gym.Space, lr: float,
                 optimizer_class: Type[torch.optim.Optimizer] = torch.optim.RMSprop,
                 optimizer_kwargs: Dict[str, Any] = {'eps': 1e-5},):
        super().__init__()
        self.observation_space = observation_space
        self.action_space = action_space
        self.lr = lr
        self.optimizer_class = optimizer_class
        self.optimizer_kwargs = dict(optimizer_kwargs)
        self.features_extractor = self.make_features_extractor()
        self.action_net = nn.Linear(self.features_extractor.features_dim, self.action_space.n)
        self.optimizer = self.optimizer_class(self.parameters(), lr=self.lr, **self.optimizer_kwargs)

    def make_features_extractor(self):
        return Encoder(self.observation_space)

    def extract_features(self, obs: torch.Tensor) -> torch.Tensor:
        obs = obs.float() / 255.
        features = self.features_extractor(obs)

        return features

    def forward(self, obs: torch.Tensor, deterministic: bool = False) -> Dict[str, torch.Tensor]:
        features = self.extract_features(obs)

        action_logits = self.action_net(features)
        distribution = Categorical(logits=action_logits)
        actions = distribution.mode() if deterministic else distribution.sample()
        actions = actions.reshape((-1, *self.action_space.shape))

        return {'features': features, 'action': actions}

    def evaluate_actions(self, obs: torch.Tensor, actions_taken: torch.Tensor) -> Dict[str, torch.Tensor]:
        features = self.extract_features(obs)
        action_logits = self.action_net(features)
        distribution = Categorical(logits=action_logits)
        log_prob = distribution.log_prob(actions_taken)
        entropy = distribution.entropy()

        return {'features': features, 'log_prob': log_prob, 'entropy': entropy}

    def set_training_mode(self, mode: bool) -> None:
        self.train(mode)

# %% [markdown]
# ### Buffer
# В буфере хранятся траектории, собранные агентом. Также в буфере производится вычисление частичных отдач по траекториям.

# %%
class BufferSamples(NamedTuple):
    observations: torch.Tensor
    actions: torch.Tensor
    returns: torch.Tensor


class Buffer:
    def __init__(
            self,
            gamma: float = 0.99,
            device: Union[torch.device, str] = "cpu",
    ):
        self.device = torch.device(device)
        self.gamma = gamma
        self.observations = None
        self.actions = None
        self.rewards = None
        self.returns = None

    def reset(self) -> None:
        self.observations = []
        self.actions = []
        self.rewards = []
        self.returns = None

    def size(self) -> int:
        return len(self.actions)

    def add(
            self,
            obs: np.ndarray,
            action: int,
            reward: float,
    ) -> None:
        self.observations.append(obs)
        self.actions.append(action)
        self.rewards.append(reward)

    def to_torch(self, array: np.ndarray) -> torch.Tensor:
        return torch.tensor(array, device=self.device)

    def _get_samples(
            self,
            batch_inds: np.ndarray,
    ) -> BufferSamples:
        observations = self.to_torch(self.observations[batch_inds])
        actions = self.to_torch(self.actions[batch_inds])
        returns = self.to_torch(self.returns[batch_inds])

        return BufferSamples(observations=observations, actions=actions, returns=returns)

    def get(self) -> BufferSamples:
        buffer_size = self.size()
        indices = np.random.permutation(buffer_size)
        self.observations = np.asarray(self.observations)
        self.actions = np.asarray(self.actions)
        self.returns = np.asarray(self.returns, dtype=np.float32)

        return self._get_samples(indices)

    def compute_returns(self) -> None:
        returns = [None] * len(self.rewards)
        reward_to_go = 0
        for step in reversed(range(len(self.rewards))):
            reward_to_go = self.rewards[step] + self.gamma * reward_to_go
            returns[step] = reward_to_go

        self.returns = returns

# %% [markdown]
# ### Обучение стратегии по методу REINFORCE
# - Метод `learn`: реализует основной цикл RL-обучения: чередование фазы сбора данных (траекторий) агентом в среде - `collect_rollouts` и фазы обучения агента - `train`.
# - Метод `collect_rollouts`: агент выполняет действия в среде согласно текущей стратегии, собирая триплеты **<observation, action, reward>** в буфер
# - Метод `train`: обучение на собранных данных. Функция потерь состоит из двух слагаемых: градиент стратегии и энтропийная регуляризация. Энтропийная регуляризация делает стратегию более стохастичной, т.е. более устойчивой к шуму, помогает исследовать среду, предотвращает сходимость к субоптимальному решению (особенно в средах с дискретными действиями)

# %% [markdown]
# ![learn](data:image/png;base64,...)

# %% [markdown]
# ![reinforce](data:image/png;base64,...)

# %%
class Reinforce:
    def __init__(
            self,
            env: gym.Env,
            learning_rate: float = 2.5e-4,
            gamma: float = 0.99,
            ent_coef: float = 0.001,
            max_grad_norm: float = 0.5,
            stats_window_size: int = 10,
            policy_class: Type[ReinforcePolicy] = ReinforcePolicy,
            policy_kwargs: Optional[Dict[str, Any]] = None,
            buffer_class: Type[Buffer] = Buffer,
            buffer_kwargs: Optional[Dict[str, Any]] = None,
            seed: Optional[int] = None,
            device: Union[torch.device, str] = "cuda",
    ):
        self.device = device if isinstance(device, torch.device) else torch.device(device)
        print(f"Using {self.device} device")

        self.policy_kwargs = {} if policy_kwargs is None else policy_kwargs

        self.num_timesteps = 0
        self._num_timesteps_at_start = 0
        self._episode_num = 0
        self.seed = seed
        self.start_time = 0.0
        self.learning_rate = learning_rate
        self._last_obs = None
        self._stats_window_size = stats_window_size
        self.ep_info_buffer = deque(maxlen=self._stats_window_size)
        self._n_updates = 0

        self.observation_space = env.observation_space
        self.action_space = env.action_space
        self.env = env

        self.n_steps = None
        self.gamma = gamma
        self.ent_coef = ent_coef
        self.max_grad_norm = max_grad_norm
        self.log_dict = {}

        self.set_random_seed(self.seed)
        self.buffer_class = buffer_class
        self.buffer_kwargs = {} if buffer_kwargs is None else buffer_kwargs
        self.buffer = self.buffer_class(
            device=self.device,
            gamma=self.gamma,
            **self.buffer_kwargs,
        )
        self.policy_class = policy_class
        self.policy = self.policy_class(
            self.observation_space, self.action_space, self.learning_rate, **self.policy_kwargs
        )
        self.policy = self.policy.to(self.device)

    def _update_info_buffer(self, info: Dict[str, Any]) -> None:
        # Collect statistics
        assert self.ep_info_buffer is not None

        ep_info = info.get("episode")
        if ep_info is not None:
            self.ep_info_buffer.append(ep_info)

    def set_random_seed(self, seed: Optional[int] = None) -> None:
        if seed is None:
            return
        set_seed_everywhere(seed, using_cuda=self.device.type == torch.device("cuda").type)
        self.action_space.seed(seed)
        self.observation_space.seed(seed)

    def collect_rollouts(
            self,
            env,
            buffer: Buffer,
    ):
        self.policy.set_training_mode(False)
        self._last_obs, _ = self.env.reset()
        self._last_obs = np.array(self._last_obs)
        assert self._last_obs is not None, "No previous observation was provided"

        buffer.reset()
        terminated = False
        while not terminated:
            with torch.no_grad():
                obs_tensor = torch.as_tensor(self._last_obs, device=self.device)
                action = self.policy(obs_tensor.unsqueeze(0))['action']
            action = action.item()
            new_obs, reward, terminated, truncated, info = env.step(action)
            assert not truncated, 'Episode truncation must be off as we want to use Monte Carlo estimation'

            self.num_timesteps += 1
            self._episode_num += int(terminated)
            buffer.add(
                self._last_obs,
                action,
                reward,
            )

            self._last_obs = np.array(new_obs)
            self._update_info_buffer(info)

        buffer.compute_returns()

    def train(self) -> None:
        self.policy.set_training_mode(True)

        rollout_data = self.buffer.get()
        actions = rollout_data.actions.long()
        policy_output = self.policy.evaluate_actions(rollout_data.observations, actions)
        log_prob = policy_output['log_prob']
        entropy = policy_output['entropy']
        returns = rollout_data.returns

        # Policy gradient loss
        policy_loss = -(returns * log_prob).mean()

        # Entropy loss
        entropy = torch.mean(entropy)
        entropy_loss = -self.ent_coef * entropy

        loss = policy_loss + entropy_loss

        # Optimization step
        self.policy.optimizer.zero_grad()
        loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
        self.policy.optimizer.step()

        self._n_updates += 1

        self.log_dict = dict([
            ("train/entropy_loss", entropy_loss.item()), ("train/entropy", entropy.item()),
            ("train/policy_gradient_loss", policy_loss.item()), ("train/loss", loss.item()),
            ("train/grad_norm", grad_norm.item()), ("train/n_updates", self._n_updates)
        ])

    def get_current_mean_return(self) -> float:
        if len(self.ep_info_buffer) == 0:
            return -math.inf

        return np.mean(np.concatenate([ep_info["r"] for ep_info in self.ep_info_buffer])).item()

    def _dump_logs(self, iteration: int) -> None:
        assert self.ep_info_buffer is not None

        time_elapsed = max((time.time_ns() - self.start_time) / 1e9, sys.float_info.epsilon)
        fps = int((self.num_timesteps - self._num_timesteps_at_start) / time_elapsed)
        self.log_dict["time/iterations"] = iteration
        if len(self.ep_info_buffer) > 0 and len(self.ep_info_buffer[0]) > 0:
            self.log_dict["rollout/ep_rew_mean"] = self.get_current_mean_return()
            self.log_dict["rollout/ep_len_mean"] = np.mean(
                np.concatenate([ep_info["l"] for ep_info in self.ep_info_buffer])).item()

        self.log_dict["time/fps"] = fps
        self.log_dict["time/time_elapsed"] = int(time_elapsed)
        self.log_dict["global_step"] = self.num_timesteps
        self.log_dict["num_episodes"] = self._episode_num
        print(self.log_dict)
        print(json.dumps(self.log_dict, sort_keys=True, indent=4))

        if WANDB_IS_AVAILABLE and wandb.run is not None:
            wandb.log(self.log_dict)

    def learn(
            self,
            max_timesteps: int,
            expected_return: float,
            log_interval: int = 1000,
            save_checkpoint_path: str = None,
            save_checkpoint_interval: int = 5000,
    ) -> None:
        assert self.env is not None

        self.start_time = time.time_ns()
        self.num_timesteps = 0
        self._episode_num = 0
        self._num_timesteps_at_start = 0
        log_interval = log_interval or math.inf
        if save_checkpoint_path is None or save_checkpoint_interval is None or not COLAB:
            save_checkpoint_interval = math.inf

        next_log_step = self.num_timesteps + log_interval
        next_save_step = self.num_timesteps + save_checkpoint_interval

        if self._last_obs is None:
            self._last_obs, _ = self.env.reset(seed=self.seed)

        iteration = 0
        while True:
            if self.get_current_mean_return() >= expected_return:
                print('Решено!')
                break

            if self.num_timesteps >= max_timesteps:
                print(f'Задача не решена за {max_timesteps} шагов')
                break

            self.collect_rollouts(self.env, self.buffer, )
            iteration += 1

            if self.num_timesteps >= next_log_step:
                assert self.ep_info_buffer is not None
                self._dump_logs(iteration)
                next_log_step += log_interval

            if self.num_timesteps >= next_save_step:
                next_save_step += save_checkpoint_interval
                checkpoint = {'policy': self.policy.state_dict(), 'optimizer': self.policy.optimizer.state_dict(),
                              'num_timesteps': self.num_timesteps, 'episode_num': self._episode_num,
                              'ep_info_buffer': self.ep_info_buffer}
                os.makedirs(save_checkpoint_path, exist_ok=True)
                torch.save(checkpoint, os.path.join(save_checkpoint_path, 'checkpoint.pt'))

            self.train()

# %%
def run_algorithm(algorithm_class, algorithm_kwargs, use_wandb, wandb_kwargs, learn_kwargs):
    env = make_env()
    model = algorithm_class(env, **algorithm_kwargs)
    if use_wandb:
        config = {}
        config.update(algorithm_kwargs)
        config.update(learn_kwargs)
        config.update(wandb_kwargs.get('config', {}))
        wandb_kwargs['config'] = config
        if wandb.run is not None:
            wandb.finish()

        wandb.init(**wandb_kwargs)

    model.learn(**learn_kwargs)
    if use_wandb:
        wandb.finish()

# %%
run_algorithm(
    algorithm_class=Reinforce,
    algorithm_kwargs=dict(seed=0, ),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                      save_checkpoint_path='/content/drive/My Drive/seminar_actor-critic/reinforce',)
)
# Out:
# Using cuda device
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: ulaelfray. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/content/wandb/run-20251101_131228-4b3ec19m</code>
# Syncing run <strong><a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/4b3ec19m' target="_blank">reinforce</a></strong> to <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a>
#  View run at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/4b3ec19m' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/4b3ec19m</a>
# {'train/entropy_loss': -0.0020789310801774263, 'train/entropy': 2.0789310932159424, 'train/policy_gradient_loss': -0.21466338634490967, 'train/loss': -0.21674232184886932, 'train/grad_norm': 0.012465535663068295, 'train/n_updates': 2, 'time/iterations': 3, 'rollout/ep_rew_mean': -76.22675323486328, 'rollout/ep_len_mean': 335.3333333333333, 'time/fps': 217, 'time/time_elapsed': 4, 'global_step': 1006, 'num_episodes': 3}
# {
#     "global_step": 1006,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 335.3333333333333,
#     "rollout/ep_rew_mean": -76.22675323486328,
#     "time/fps": 217,
#     "time/iterations": 3,
#     "time/time_elapsed": 4,
#     "train/entropy": 2.0789310932159424,
#     "train/entropy_loss": -0.0020789310801774263,
#     "train/grad_norm": 0.012465535663068295,
#     "train/loss": -0.21674232184886932,
#     "train/n_updates": 2,
#     "train/policy_gradient_loss": -0.21466338634490967
# }
# {'train/entropy_loss': -0.002078867983072996, 'train/entropy': 2.0788679122924805, 'train/policy_gradient_loss': -0.49981966614723206, 'train/loss': -0.5018985271453857, 'train/grad_norm': 0.025441385805606842, 'train/n_updates': 5, 'time/iterations': 6, 'rollout/ep_rew_mean': -68.12448120117188, 'rollout/ep_len_mean': 365.5, 'time/fps': 186, 'time/time_elapsed': 11, 'global_step': 2193, 'num_episodes': 6}
# {
#     "global_step": 2193,
#     "num_episodes": 6,
#     "rollout/ep_len_mean": 365.5,
#     "rollout/ep_rew_mean": -68.12448120117188,
#     "time/fps": 186,
#     "time/iterations": 6,
#     "time/time_elapsed": 11,
#     "train/entropy": 2.0788679122924805,
#     "train/entropy_loss": -0.002078867983072996,
#     "train/grad_norm": 0.025441385805606842,
#     "train/loss": -0.5018985271453857,
#     "train/n_updates": 5,
#     "train/policy_gradient_loss": -0.49981966614723206
# }
# {'train/entropy_loss': -0.002076836535707116, 'train/entropy': 2.076836347579956, 'train/policy_gradient_loss': -0.32379356026649475, 'train/loss': -0.3258703947067261, 'train/grad_norm': 0.018119189888238907, 'train/n_updates': 6, 'time/iterations': 7, 'rollout/ep_rew_mean': -54.66374969482422, 'rollout/ep_len_mean': 613.2857142857143, 'time/fps': 246, 'time/time_elapsed': 17, 'global_step': 4293, 'num_episodes': 7}
# {
#     "global_step": 4293,
#     "num_episodes": 7,
#     "rollout/ep_len_mean": 613.2857142857143,
#     "rollout/ep_rew_mean": -54.66374969482422,
#     "time/fps": 246,
#     "time/iterations": 7,
#     "time/time_elapsed": 17,
#     "train/entropy": 2.076836347579956,
#     "train/entropy_loss": -0.002076836535707116,
#     "train/grad_norm": 0.018119189888238907,
#     "train/loss": -0.3258703947067261,
#     "train/n_updates": 6,
#     "train/policy_gradient_loss": -0.32379356026649475
# }
# {'train/entropy_loss': -0.0020744323264807463, 'train/entropy': 2.074432134628296, 'train/policy_gradient_loss': 0.027744242921471596, 'train/loss': 0.02566981129348278, 'train/grad_norm': 0.005937820766121149, 'train/n_updates': 7, 'time/iterations': 8, 'rollout/ep_rew_mean': -55.357566833496094, 'rollout/ep_len_mean': 587.375, 'time/fps': 248, 'time/time_elapsed': 18, 'global_step': 4699, 'num_episodes': 8}
# {
#     "global_step": 4699,
#     "num_episodes": 8,
#     "rollout/ep_len_mean": 587.375,
#     "rollout/ep_rew_mean": -55.357566833496094,
#     "time/fps": 248,
#     "time/iterations": 8,
#     "time/time_elapsed": 18,
#     "train/entropy": 2.074432134628296,
#     "train/entropy_loss": -0.0020744323264807463,
#     "train/grad_norm": 0.005937820766121149,
#     "train/loss": 0.02566981129348278,
#     "train/n_updates": 7,
#     "train/policy_gradient_loss": 0.027744242921471596
# }
# {'train/entropy_loss': -0.0020750623662024736, 'train/entropy': 2.0750622749328613, 'train/policy_gradient_loss': -0.28598079085350037, 'train/loss': -0.2880558669567108, 'train/grad_norm': 0.03104863315820694, 'train/n_updates': 8, 'time/iterations': 9, 'rollout/ep_rew_mean': -59.53130340576172, 'rollout/ep_len_mean': 579.0, 'time/fps': 259, 'time/time_elapsed': 20, 'global_step': 5211, 'num_episodes': 9}
# {
#     "global_step": 5211,
#     "num_episodes": 9,
#     "rollout/ep_len_mean": 579.0,
#     "rollout/ep_rew_mean": -59.53130340576172,
#     "time/fps": 259,
#     "time/iterations": 9,
#     "time/time_elapsed": 20,
#     "train/entropy": 2.0750622749328613,
#     "train/entropy_loss": -0.0020750623662024736,
#     "train/grad_norm": 0.03104863315820694,
#     "train/loss": -0.2880558669567108,
#     "train/n_updates": 8,
#     "train/policy_gradient_loss": -0.28598079085350037
# }
# {'train/entropy_loss': -0.002066114917397499, 'train/entropy': 2.066114902496338, 'train/policy_gradient_loss': -0.44335150718688965, 'train/loss': -0.4454176127910614, 'train/grad_norm': 0.03470093011856079, 'train/n_updates': 11, 'time/iterations': 12, 'rollout/ep_rew_mean': -46.086456298828125, 'rollout/ep_len_mean': 550.6, 'time/fps': 275, 'time/time_elapsed': 22, 'global_step': 6125, 'num_episodes': 12}
# {
#     "global_step": 6125,
#     "num_episodes": 12,
#     "rollout/ep_len_mean": 550.6,
#     "rollout/ep_rew_mean": -46.086456298828125,
#     "time/fps": 275,
#     "time/iterations": 12,
#     "time/time_elapsed": 22,
#     "train/entropy": 2.066114902496338,
#     "train/entropy_loss": -0.002066114917397499,
#     "train/grad_norm": 0.03470093011856079,
#     "train/loss": -0.4454176127910614,
#     "train/n_updates": 11,
#     "train/policy_gradient_loss": -0.44335150718688965
# }
# {'train/entropy_loss': -5.872423258779236e-08, 'train/entropy': 5.872422843822278e-05, 'train/policy_gradient_loss': 3.826382817351259e-05, 'train/loss': 3.820510391960852e-05, 'train/grad_norm': 0.002882734639570117, 'train/n_updates': 16, 'time/iterations': 17, 'rollout/ep_rew_mean': 726.15625, 'rollout/ep_len_mean': 270.8, 'time/fps': 289, 'time/time_elapsed': 24, 'global_step': 7001, 'num_episodes': 17}
# {
#     "global_step": 7001,
#     "num_episodes": 17,
#     "rollout/ep_len_mean": 270.8,
#     "rollout/ep_rew_mean": 726.15625,
#     "time/fps": 289,
#     "time/iterations": 17,
#     "time/time_elapsed": 24,
#     "train/entropy": 5.872422843822278e-05,
#     "train/entropy_loss": -5.872423258779236e-08,
#     "train/grad_norm": 0.002882734639570117,
#     "train/loss": 3.820510391960852e-05,
#     "train/n_updates": 16,
#     "train/policy_gradient_loss": 3.826382817351259e-05
# }
# {'train/entropy_loss': -3.000254977791883e-08, 'train/entropy': 3.0002549465280026e-05, 'train/policy_gradient_loss': 1.7535463484819047e-05, 'train/loss': 1.7505461073596962e-05, 'train/grad_norm': 0.00141418247949332, 'train/n_updates': 22, 'time/iterations': 23, 'rollout/ep_rew_mean': 2101.619140625, 'rollout/ep_len_mean': 163.8, 'time/fps': 301, 'time/time_elapsed': 26, 'global_step': 8003, 'num_episodes': 23}
# {
#     "global_step": 8003,
#     "num_episodes": 23,
#     "rollout/ep_len_mean": 163.8,
#     "rollout/ep_rew_mean": 2101.619140625,
#     "time/fps": 301,
#     "time/iterations": 23,
#     "time/time_elapsed": 26,
#     "train/entropy": 3.0002549465280026e-05,
#     "train/entropy_loss": -3.000254977791883e-08,
#     "train/grad_norm": 0.00141418247949332,
#     "train/loss": 1.7505461073596962e-05,
#     "train/n_updates": 22,
#     "train/policy_gradient_loss": 1.7535463484819047e-05
# }
# Решено!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▂▄▅▅▆▇█</td></tr><tr><td>num_episodes</td><td>▁▂▂▃▃▄▆█</td></tr><tr><td>rollout/ep_len_mean</td><td>▄▄██▇▇▃▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁▁▁▄█</td></tr><tr><td>time/fps</td><td>▃▁▅▅▅▆▇█</td></tr><tr><td>time/iterations</td><td>▁▂▂▃▃▄▆█</td></tr><tr><td>time/time_elapsed</td><td>▁▃▅▅▆▇▇█</td></tr><tr><td>train/entropy</td><td>██████▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁▁██</td></tr><tr><td>train/grad_norm</td><td>▃▆▅▂▇█▁▁</td></tr><tr><td>train/loss</td><td>▅▁▃█▄▂██</td></tr><tr><td>train/n_updates</td><td>▁▂▂▃▃▄▆█</td></tr><tr><td>train/policy_gradient_loss</td><td>▅▁▃█▄▂██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>8003</td></tr><tr><td>num_episodes</td><td>23</td></tr><tr><td>rollout/ep_len_mean</td><td>163.8</td></tr><tr><td>rollout/ep_rew_mean</td><td>2101.61914</td></tr><tr><td>time/fps</td><td>301</td></tr><tr><td>time/iterations</td><td>23</td></tr><tr><td>time/time_elapsed</td><td>26</td></tr><tr><td>train/entropy</td><td>3e-05</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>0.00141</td></tr><tr><td>train/loss</td><td>2e-05</td></tr><tr><td>train/n_updates</td><td>22</td></tr><tr><td>train/policy_gradient_loss</td><td>2e-05</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">reinforce</strong> at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/4b3ec19m' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/4b3ec19m</a><br> View project at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251101_131228-4b3ec19m/logs</code>

# %% [markdown]
# # 2 REINFORCE с базовым уровнем
# Градиент стратагии зависит от величины отдачи. Однако отдача может быть очень шумной оценкой $Q ^ {\pi} (s, a)$, особенно в средах с отложенными или редкими вознаграждениями. Этот шум приводит к высокой дисперсии в оценках градиента, что влечёт за собой сильные изменения стратегии. При этом обучение становится нестабильным, а сходимость медленной. Одним из способов снижения дисперсии является использование базового уровня $b(s)$. Базовый уровень $b(s)$ не зависит от действий, поэтому вычитание из оценки $Q ^ {\pi} (s, a)$ не приводит к смещению оценки градиента.
#
# $$\nabla_\theta J(\theta) = \mathbb{E}_\pi [(G_t - b(s)) \nabla_\theta \ln \pi_\theta(a_t \vert s_t)]$$
#
# ## 2.1 REINFORCE с необучаемым базовым уровнем (средняя отдача)
# В некоторых случаях в качестве базового уровня достаточно использовать среднюю отдачу за предыдущие эпизоды. Даже такая простая эвристика может помочь стабилизировать процесс обучения на ранних этапах.

# %% [markdown]
# (3 балла)

# %%
# AverageReturnBuffer хранит статистику - среднюю отдачу по всем состояниям и эпизодам за время обучения
class AverageReturnBuffer(Buffer):
    def __init__(self, gamma: float = 0.99, device: Union[torch.device, str] = "cpu"):
        # Дополнительные переменные, необходимые для вычисления средней отдачи
        super().__init__(gamma, device)
        self.average_return = 0
        self.all_returns = []

    def get_average_return(self):
        return self.average_return

    def compute_returns(self) -> None:
        # average_returns = {}
        returns = [None] * len(self.rewards)
        reward_to_go = 0
        for step in reversed(range(len(self.rewards))):
            obs = self.observations[step]
            reward_to_go = self.rewards[step] + self.gamma * reward_to_go
            returns[step] = reward_to_go

        self.all_returns.extend(returns)
        self.average_return = np.mean(self.all_returns)

        self.returns = returns

# %% [markdown]
# (1 балл)

# %%
class AverageReturnBaselineReinforce(Reinforce):
    def __init__(self, env: gym.Env, learning_rate: float = 2.5e-4, gamma: float = 0.99, ent_coef: float = 0.001,
                 max_grad_norm: float = 0.5, stats_window_size: int = 10, policy_class: Type[ReinforcePolicy] = ReinforcePolicy,
                 policy_kwargs: Optional[Dict[str, Any]] = None, buffer_class: Type[AverageReturnBuffer] = AverageReturnBuffer,
                 buffer_kwargs: Optional[Dict[str, Any]] = None, seed: Optional[int] = None,
                 device: Union[torch.device, str] = "cuda"):
        super().__init__(env, learning_rate, gamma, ent_coef, max_grad_norm, stats_window_size, policy_class, policy_kwargs,
                         buffer_class, buffer_kwargs, seed, device)

    def train(self) -> None:
        self.policy.set_training_mode(True)

        rollout_data = self.buffer.get()
        actions = rollout_data.actions.long()
        policy_output = self.policy.evaluate_actions(rollout_data.observations, actions)
        log_prob = policy_output['log_prob']
        entropy = policy_output['entropy']

        # Получаем среднюю отдачу
        baseline = self.buffer.get_average_return()
        returns = rollout_data.returns

        # Посчитать отдачи с учётом базового уровня
        returns = returns - baseline
        # raise NotImplementedError

        # Policy gradient loss
        policy_loss = -(returns * log_prob).mean()

        # Entropy loss
        entropy = torch.mean(entropy)
        entropy_loss = -self.ent_coef * entropy

        loss = policy_loss + entropy_loss

        # Optimization step
        self.policy.optimizer.zero_grad()
        loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
        self.policy.optimizer.step()

        self._n_updates += 1

        self.log_dict = dict([
            ("train/entropy_loss", entropy_loss.item()), ("train/entropy", entropy.item()),
            ("train/policy_gradient_loss", policy_loss.item()), ("train/loss", loss.item()),
            ("train/grad_norm", grad_norm.item()), ("train/n_updates", self._n_updates),
            ("train/baseline", baseline)
        ])

# %%
run_algorithm(
    algorithm_class=AverageReturnBaselineReinforce,
    algorithm_kwargs=dict(seed=0, ),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_simple-baseline'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                    save_checkpoint_path='/content/drive/My Drive/seminar_actor-critic/reinforce_simple-baseline')
)
# Out:
# /usr/local/lib/python3.12/dist-packages/vizdoom/gymnasium_wrapper/base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# Using cuda device
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/content/wandb/run-20251101_131836-o37krn7g</code>
# Syncing run <strong><a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/o37krn7g' target="_blank">reinforce_simple-baseline</a></strong> to <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a>
#  View run at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/o37krn7g' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/o37krn7g</a>
# {'train/entropy_loss': -0.00207862863317132, 'train/entropy': 2.0786285400390625, 'train/policy_gradient_loss': 0.07972339540719986, 'train/loss': 0.07764476537704468, 'train/grad_norm': 0.01766599528491497, 'train/n_updates': 3, 'train/baseline': np.float64(-0.2611531089486), 'time/iterations': 4, 'rollout/ep_rew_mean': -71.22537994384766, 'rollout/ep_len_mean': 407.5, 'time/fps': 446, 'time/time_elapsed': 3, 'global_step': 1630, 'num_episodes': 4}
# {
#     "global_step": 1630,
#     "num_episodes": 4,
#     "rollout/ep_len_mean": 407.5,
#     "rollout/ep_rew_mean": -71.22537994384766,
#     "time/fps": 446,
#     "time/iterations": 4,
#     "time/time_elapsed": 3,
#     "train/baseline": -0.2611531089486,
#     "train/entropy": 2.0786285400390625,
#     "train/entropy_loss": -0.00207862863317132,
#     "train/grad_norm": 0.01766599528491497,
#     "train/loss": 0.07764476537704468,
#     "train/n_updates": 3,
#     "train/policy_gradient_loss": 0.07972339540719986
# }
# {'train/entropy_loss': -0.0020791629794985056, 'train/entropy': 2.079162836074829, 'train/policy_gradient_loss': 0.22792671620845795, 'train/loss': 0.22584755718708038, 'train/grad_norm': 0.01798255369067192, 'train/n_updates': 4, 'train/baseline': np.float64(-0.16504755269366853), 'time/iterations': 5, 'rollout/ep_rew_mean': -70.7961654663086, 'rollout/ep_len_mean': 448.0, 'time/fps': 304, 'time/time_elapsed': 7, 'global_step': 2240, 'num_episodes': 5}
# {
#     "global_step": 2240,
#     "num_episodes": 5,
#     "rollout/ep_len_mean": 448.0,
#     "rollout/ep_rew_mean": -70.7961654663086,
#     "time/fps": 304,
#     "time/iterations": 5,
#     "time/time_elapsed": 7,
#     "train/baseline": -0.16504755269366853,
#     "train/entropy": 2.079162836074829,
#     "train/entropy_loss": -0.0020791629794985056,
#     "train/grad_norm": 0.01798255369067192,
#     "train/loss": 0.22584755718708038,
#     "train/n_updates": 4,
#     "train/policy_gradient_loss": 0.22792671620845795
# }
# {'train/entropy_loss': -0.002079043537378311, 'train/entropy': 2.079043388366699, 'train/policy_gradient_loss': 0.06575097143650055, 'train/loss': 0.06367193162441254, 'train/grad_norm': 0.009951060637831688, 'train/n_updates': 5, 'train/baseline': np.float64(-0.15325325581661586), 'time/iterations': 6, 'rollout/ep_rew_mean': -55.83357620239258, 'rollout/ep_len_mean': 608.5, 'time/fps': 327, 'time/time_elapsed': 11, 'global_step': 3651, 'num_episodes': 6}
# {
#     "global_step": 3651,
#     "num_episodes": 6,
#     "rollout/ep_len_mean": 608.5,
#     "rollout/ep_rew_mean": -55.83357620239258,
#     "time/fps": 327,
#     "time/iterations": 6,
#     "time/time_elapsed": 11,
#     "train/baseline": -0.15325325581661586,
#     "train/entropy": 2.079043388366699,
#     "train/entropy_loss": -0.002079043537378311,
#     "train/grad_norm": 0.009951060637831688,
#     "train/loss": 0.06367193162441254,
#     "train/n_updates": 5,
#     "train/policy_gradient_loss": 0.06575097143650055
# }
# {'train/entropy_loss': -0.002079148543998599, 'train/entropy': 2.079148530960083, 'train/policy_gradient_loss': 0.21818430721759796, 'train/loss': 0.2161051630973816, 'train/grad_norm': 0.0062621114775538445, 'train/n_updates': 6, 'train/baseline': np.float64(-0.08708825714702917), 'time/iterations': 7, 'rollout/ep_rew_mean': -61.34478759765625, 'rollout/ep_len_mean': 585.0, 'time/fps': 325, 'time/time_elapsed': 12, 'global_step': 4095, 'num_episodes': 7}
# {
#     "global_step": 4095,
#     "num_episodes": 7,
#     "rollout/ep_len_mean": 585.0,
#     "rollout/ep_rew_mean": -61.34478759765625,
#     "time/fps": 325,
#     "time/iterations": 7,
#     "time/time_elapsed": 12,
#     "train/baseline": -0.08708825714702917,
#     "train/entropy": 2.079148530960083,
#     "train/entropy_loss": -0.002079148543998599,
#     "train/grad_norm": 0.0062621114775538445,
#     "train/loss": 0.2161051630973816,
#     "train/n_updates": 6,
#     "train/policy_gradient_loss": 0.21818430721759796
# }
# {'train/entropy_loss': -0.002077422570437193, 'train/entropy': 2.0774223804473877, 'train/policy_gradient_loss': -0.23113122582435608, 'train/loss': -0.23320864140987396, 'train/grad_norm': 0.042457565665245056, 'train/n_updates': 9, 'train/baseline': np.float64(-0.1276406742315912), 'time/iterations': 10, 'rollout/ep_rew_mean': -57.40576934814453, 'rollout/ep_len_mean': 527.5, 'time/fps': 338, 'time/time_elapsed': 15, 'global_step': 5275, 'num_episodes': 10}
# {
#     "global_step": 5275,
#     "num_episodes": 10,
#     "rollout/ep_len_mean": 527.5,
#     "rollout/ep_rew_mean": -57.40576934814453,
#     "time/fps": 338,
#     "time/iterations": 10,
#     "time/time_elapsed": 15,
#     "train/baseline": -0.1276406742315912,
#     "train/entropy": 2.0774223804473877,
#     "train/entropy_loss": -0.002077422570437193,
#     "train/grad_norm": 0.042457565665245056,
#     "train/loss": -0.23320864140987396,
#     "train/n_updates": 9,
#     "train/policy_gradient_loss": -0.23113122582435608
# }
# {'train/entropy_loss': -7.474430674392352e-08, 'train/entropy': 7.47443045838736e-05, 'train/policy_gradient_loss': 4.802827970706858e-05, 'train/loss': 4.795353379449807e-05, 'train/grad_norm': 0.0034847890492528677, 'train/n_updates': 13, 'train/baseline': np.float64(0.44677565113070333), 'time/iterations': 14, 'rollout/ep_rew_mean': 673.562255859375, 'rollout/ep_len_mean': 438.4, 'time/fps': 347, 'time/time_elapsed': 17, 'global_step': 6014, 'num_episodes': 14}
# {
#     "global_step": 6014,
#     "num_episodes": 14,
#     "rollout/ep_len_mean": 438.4,
#     "rollout/ep_rew_mean": 673.562255859375,
#     "time/fps": 347,
#     "time/iterations": 14,
#     "time/time_elapsed": 17,
#     "train/baseline": 0.44677565113070333,
#     "train/entropy": 7.47443045838736e-05,
#     "train/entropy_loss": -7.474430674392352e-08,
#     "train/grad_norm": 0.0034847890492528677,
#     "train/loss": 4.795353379449807e-05,
#     "train/n_updates": 13,
#     "train/policy_gradient_loss": 4.802827970706858e-05
# }
# {'train/entropy_loss': -2.894274686582321e-08, 'train/entropy': 2.8942746212123893e-05, 'train/policy_gradient_loss': 1.4169252608553506e-05, 'train/loss': 1.4140309758658987e-05, 'train/grad_norm': 0.0011279028840363026, 'train/n_updates': 19, 'train/baseline': np.float64(1.7247942509287224), 'time/iterations': 20, 'rollout/ep_rew_mean': 2070.71044921875, 'rollout/ep_len_mean': 174.2, 'time/fps': 357, 'time/time_elapsed': 19, 'global_step': 7017, 'num_episodes': 20}
# {
#     "global_step": 7017,
#     "num_episodes": 20,
#     "rollout/ep_len_mean": 174.2,
#     "rollout/ep_rew_mean": 2070.71044921875,
#     "time/fps": 357,
#     "time/iterations": 20,
#     "time/time_elapsed": 19,
#     "train/baseline": 1.7247942509287224,
#     "train/entropy": 2.8942746212123893e-05,
#     "train/entropy_loss": -2.894274686582321e-08,
#     "train/grad_norm": 0.0011279028840363026,
#     "train/loss": 1.4140309758658987e-05,
#     "train/n_updates": 19,
#     "train/policy_gradient_loss": 1.4169252608553506e-05
# }
# Решено!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▂▄▄▆▇█</td></tr><tr><td>num_episodes</td><td>▁▁▂▂▄▅█</td></tr><tr><td>rollout/ep_len_mean</td><td>▅▅██▇▅▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁▁▃█</td></tr><tr><td>time/fps</td><td>█▁▂▂▃▃▄</td></tr><tr><td>time/iterations</td><td>▁▁▂▂▄▅█</td></tr><tr><td>time/time_elapsed</td><td>▁▃▅▅▆▇█</td></tr><tr><td>train/baseline</td><td>▁▁▁▂▁▃█</td></tr><tr><td>train/entropy</td><td>█████▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁██</td></tr><tr><td>train/grad_norm</td><td>▄▄▂▂█▁▁</td></tr><tr><td>train/loss</td><td>▆█▆█▁▅▅</td></tr><tr><td>train/n_updates</td><td>▁▁▂▂▄▅█</td></tr><tr><td>train/policy_gradient_loss</td><td>▆█▆█▁▅▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>7017</td></tr><tr><td>num_episodes</td><td>20</td></tr><tr><td>rollout/ep_len_mean</td><td>174.2</td></tr><tr><td>rollout/ep_rew_mean</td><td>2070.71045</td></tr><tr><td>time/fps</td><td>357</td></tr><tr><td>time/iterations</td><td>20</td></tr><tr><td>time/time_elapsed</td><td>19</td></tr><tr><td>train/baseline</td><td>1.72479</td></tr><tr><td>train/entropy</td><td>3e-05</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>0.00113</td></tr><tr><td>train/loss</td><td>1e-05</td></tr><tr><td>train/n_updates</td><td>19</td></tr><tr><td>train/policy_gradient_loss</td><td>1e-05</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">reinforce_simple-baseline</strong> at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/o37krn7g' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/o37krn7g</a><br> View project at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251101_131836-o37krn7g/logs</code>

# %% [markdown]
# ## 2.2 REINFORCE с обучаемым базовым уровнем
# Чаще всего в качестве базового уровня применяется оценка функции полезности состояний $b(s) = v(s) = \mathbb{E}[G_t| s_t = s]$, получаемая с помощью нейросетевой аппроксимации. При этом величину $G_t - b(s_t)$ можно рассматривать как оценку функции преимущества (advantage) действия $a_t$ в состоянии $s_t$: $A(s_t, a_t) = Q(s_t, a_t) - V(s_t)$.
#
# #### Shared-encoder
# Модели стратегии и функции полезности могут обучаться в разных режимах — стратегия только on-policy (шаг обучения на текущей собранной подтраектории), а полезность on-policy или off-policy (шаг обучения на текущей подтраектории или на батче из replay buffer). Это с одной стороны привносит гибкость в обучение, с другой — усложняет его.
#
# Если обе модели обучаются on-policy, то имеет смысл объединить их сетки в одну и делать общий шаг обратного распространения ошибки. Однако, если они обучаются в разных режимах (и с разной частотой обновления), то велика вероятность, что их шаги обучения могут начать конфликтовать в случае общего тела — для такого варианта намного предпочтительнее разделить их на разные подсети (либо аккуратно настраивать гиперпарметры, чтобы стабилизировать обучение). В целом, рекомендуется использовать общий энкодер наблюдений, а далее как можно скорее разделять головы.

# %% [markdown]
# (2 балла)

# %%
class ValuePolicy(ReinforcePolicy):
    def __init__(self, observation_space: gym.Space, action_space: gym.Space, lr: float,
                 optimizer_class: Type[torch.optim.Optimizer] = torch.optim.RMSprop,
                 optimizer_kwargs: Dict[str, Any] = {'eps': 1e-5}):
        # Добавить слой для вычисления полезности состояний
        # self.value_net = ...
        super().__init__(observation_space, action_space, lr, optimizer_class, optimizer_kwargs)
        self.value_net = nn.Sequential(
            self.features_extractor,
            nn.Linear(self.features_extractor.features_dim, 1)
        )
        # self.action_net = nn.Linear(self.features_extractor.features_dim, self.action_space.n)

    def evaluate_actions(self, obs: torch.Tensor, actions_taken: torch.Tensor) -> Dict[str, torch.Tensor]:
        # Метод должен возвращать словарь с 'features', 'log_prob', 'entropy' и 'values' - полезность obs
        features = self.extract_features(obs)
        action_logits = self.action_net(features)
        distribution = Categorical(logits=action_logits)
        log_prob = distribution.log_prob(actions_taken)
        entropy = distribution.entropy()
        obs = obs.float() / 255
        values = self.value_net(obs)

        return {'features': features, 'log_prob': log_prob, 'entropy': entropy, 'value': values}

# %% [markdown]
# (1 балл)

# %%
class ValueBaselineReinforce(Reinforce):
    def __init__(self, env: gym.Env, learning_rate: float = 2.5e-4, gamma: float = 0.99, ent_coef: float = 0.001,
                 max_grad_norm: float = 0.5, stats_window_size: int = 10, policy_class: Type[ValuePolicy] = ValuePolicy,
                 policy_kwargs: Optional[Dict[str, Any]] = None, buffer_class: Type[Buffer] = Buffer,
                 buffer_kwargs: Optional[Dict[str, Any]] = None, seed: Optional[int] = None,
                 device: Union[torch.device, str] = "cuda", vf_coef: float = 0.5,):
        super().__init__(env, learning_rate, gamma, ent_coef, max_grad_norm, stats_window_size, policy_class,
                         policy_kwargs, buffer_class, buffer_kwargs, seed, device)
        self.vf_coef = vf_coef

    def train(self) -> None:
        self.policy.set_training_mode(True)

        rollout_data = self.buffer.get()
        actions = rollout_data.actions.long()
        policy_output = self.policy.evaluate_actions(rollout_data.observations, actions)
        log_prob = policy_output['log_prob']
        entropy = policy_output['entropy']
        values = policy_output['value']
        advantages = rollout_data.returns - values.detach()
        baseline = values.mean().item()

        # Policy gradient loss
        policy_loss = -(advantages * log_prob).mean()

        # Entropy loss
        entropy = torch.mean(entropy)
        entropy_loss = -self.ent_coef * entropy

        # Value loss с коэффициентов self.vf_coef
        value_loss = self.vf_coef * (advantages ** 2).mean()
        # raise NotImplementedError

        loss = policy_loss + entropy_loss + value_loss

        # Optimization step
        self.policy.optimizer.zero_grad()
        loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
        self.policy.optimizer.step()

        self._n_updates += 1

        self.log_dict = dict([
            ("train/entropy_loss", entropy_loss.item()), ("train/entropy", entropy.item()),
            ("train/policy_gradient_loss", policy_loss.item()), ("train/loss", loss.item()),
            ("train/grad_norm", grad_norm.item()), ("train/n_updates", self._n_updates),
            ("train/baseline", baseline), ("train/value_loss", value_loss.item())
        ])

# %%
run_algorithm(
    algorithm_class=ValueBaselineReinforce,
    algorithm_kwargs=dict(seed=0, ),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_value-baseline'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                    save_checkpoint_path='/content/drive/My Drive/seminar_actor-critic/reinforce_value-baseline')
)
# Out:
# Using cuda device
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/content/wandb/run-20251101_131932-7z4dq9v9</code>
# Syncing run <strong><a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/7z4dq9v9' target="_blank">reinforce_value-baseline</a></strong> to <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a>
#  View run at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/7z4dq9v9' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/7z4dq9v9</a>
# {'train/entropy_loss': -0.0020789504051208496, 'train/entropy': 2.0789504051208496, 'train/policy_gradient_loss': -0.17543958127498627, 'train/loss': -0.15104304254055023, 'train/grad_norm': 0.011791315861046314, 'train/n_updates': 2, 'train/baseline': -0.018875885754823685, 'train/value_loss': 0.026475494727492332, 'time/iterations': 3, 'rollout/ep_rew_mean': -87.36968994140625, 'rollout/ep_len_mean': 347.3333333333333, 'time/fps': 441, 'time/time_elapsed': 2, 'global_step': 1042, 'num_episodes': 3}
# {
#     "global_step": 1042,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 347.3333333333333,
#     "rollout/ep_rew_mean": -87.36968994140625,
#     "time/fps": 441,
#     "time/iterations": 3,
#     "time/time_elapsed": 2,
#     "train/baseline": -0.018875885754823685,
#     "train/entropy": 2.0789504051208496,
#     "train/entropy_loss": -0.0020789504051208496,
#     "train/grad_norm": 0.011791315861046314,
#     "train/loss": -0.15104304254055023,
#     "train/n_updates": 2,
#     "train/policy_gradient_loss": -0.17543958127498627,
#     "train/value_loss": 0.026475494727492332
# }
# {'train/entropy_loss': -0.0020769478287547827, 'train/entropy': 2.0769476890563965, 'train/policy_gradient_loss': 0.29366186261177063, 'train/loss': 0.362956702709198, 'train/grad_norm': 0.02747105062007904, 'train/n_updates': 4, 'train/baseline': -0.02135060355067253, 'train/value_loss': 0.07137177884578705, 'time/iterations': 5, 'rollout/ep_rew_mean': -42.03038024902344, 'rollout/ep_len_mean': 424.2, 'time/fps': 262, 'time/time_elapsed': 8, 'global_step': 2121, 'num_episodes': 5}
# {
#     "global_step": 2121,
#     "num_episodes": 5,
#     "rollout/ep_len_mean": 424.2,
#     "rollout/ep_rew_mean": -42.03038024902344,
#     "time/fps": 262,
#     "time/iterations": 5,
#     "time/time_elapsed": 8,
#     "train/baseline": -0.02135060355067253,
#     "train/entropy": 2.0769476890563965,
#     "train/entropy_loss": -0.0020769478287547827,
#     "train/grad_norm": 0.02747105062007904,
#     "train/loss": 0.362956702709198,
#     "train/n_updates": 4,
#     "train/policy_gradient_loss": 0.29366186261177063,
#     "train/value_loss": 0.07137177884578705
# }
# {'train/entropy_loss': -0.0020588154438883066, 'train/entropy': 2.0588152408599854, 'train/policy_gradient_loss': -0.4530874490737915, 'train/loss': -0.38669994473457336, 'train/grad_norm': 0.05608859658241272, 'train/n_updates': 7, 'train/baseline': -0.07223858684301376, 'train/value_loss': 0.06844630837440491, 'time/iterations': 8, 'rollout/ep_rew_mean': -35.76115417480469, 'rollout/ep_len_mean': 384.625, 'time/fps': 299, 'time/time_elapsed': 10, 'global_step': 3077, 'num_episodes': 8}
# {
#     "global_step": 3077,
#     "num_episodes": 8,
#     "rollout/ep_len_mean": 384.625,
#     "rollout/ep_rew_mean": -35.76115417480469,
#     "time/fps": 299,
#     "time/iterations": 8,
#     "time/time_elapsed": 10,
#     "train/baseline": -0.07223858684301376,
#     "train/entropy": 2.0588152408599854,
#     "train/entropy_loss": -0.0020588154438883066,
#     "train/grad_norm": 0.05608859658241272,
#     "train/loss": -0.38669994473457336,
#     "train/n_updates": 7,
#     "train/policy_gradient_loss": -0.4530874490737915,
#     "train/value_loss": 0.06844630837440491
# }
# {'train/entropy_loss': -0.0020679160952568054, 'train/entropy': 2.067915916442871, 'train/policy_gradient_loss': -0.2529216408729553, 'train/loss': -0.14483121037483215, 'train/grad_norm': 0.0603257492184639, 'train/n_updates': 11, 'train/baseline': -0.04877552390098572, 'train/value_loss': 0.11015836149454117, 'time/iterations': 12, 'rollout/ep_rew_mean': 4.457353115081787, 'rollout/ep_len_mean': 367.7, 'time/fps': 315, 'time/time_elapsed': 13, 'global_step': 4296, 'num_episodes': 12}
# {
#     "global_step": 4296,
#     "num_episodes": 12,
#     "rollout/ep_len_mean": 367.7,
#     "rollout/ep_rew_mean": 4.457353115081787,
#     "time/fps": 315,
#     "time/iterations": 12,
#     "time/time_elapsed": 13,
#     "train/baseline": -0.04877552390098572,
#     "train/entropy": 2.067915916442871,
#     "train/entropy_loss": -0.0020679160952568054,
#     "train/grad_norm": 0.0603257492184639,
#     "train/loss": -0.14483121037483215,
#     "train/n_updates": 11,
#     "train/policy_gradient_loss": -0.2529216408729553,
#     "train/value_loss": 0.11015836149454117
# }
# {'train/entropy_loss': -0.0004580221138894558, 'train/entropy': 0.4580220878124237, 'train/policy_gradient_loss': 0.2618007957935333, 'train/loss': 0.5329256653785706, 'train/grad_norm': 0.108151376247406, 'train/n_updates': 14, 'train/baseline': -0.5328589081764221, 'train/value_loss': 0.2715829014778137, 'time/iterations': 15, 'rollout/ep_rew_mean': 86.50858306884766, 'rollout/ep_len_mean': 313.1, 'time/fps': 332, 'time/time_elapsed': 15, 'global_step': 5252, 'num_episodes': 15}
# {
#     "global_step": 5252,
#     "num_episodes": 15,
#     "rollout/ep_len_mean": 313.1,
#     "rollout/ep_rew_mean": 86.50858306884766,
#     "time/fps": 332,
#     "time/iterations": 15,
#     "time/time_elapsed": 15,
#     "train/baseline": -0.5328589081764221,
#     "train/entropy": 0.4580220878124237,
#     "train/entropy_loss": -0.0004580221138894558,
#     "train/grad_norm": 0.108151376247406,
#     "train/loss": 0.5329256653785706,
#     "train/n_updates": 14,
#     "train/policy_gradient_loss": 0.2618007957935333,
#     "train/value_loss": 0.2715829014778137
# }
# {'train/entropy_loss': -0.0010595793137326837, 'train/entropy': 1.0595792531967163, 'train/policy_gradient_loss': 2.5736083984375, 'train/loss': 6.097572326660156, 'train/grad_norm': 1.2647496461868286, 'train/n_updates': 17, 'train/baseline': -0.2845970392227173, 'train/value_loss': 3.5250232219696045, 'time/iterations': 18, 'rollout/ep_rew_mean': 296.10418701171875, 'rollout/ep_len_mean': 311.0, 'time/fps': 341, 'time/time_elapsed': 18, 'global_step': 6187, 'num_episodes': 18}
# {
#     "global_step": 6187,
#     "num_episodes": 18,
#     "rollout/ep_len_mean": 311.0,
#     "rollout/ep_rew_mean": 296.10418701171875,
#     "time/fps": 341,
#     "time/iterations": 18,
#     "time/time_elapsed": 18,
#     "train/baseline": -0.2845970392227173,
#     "train/entropy": 1.0595792531967163,
#     "train/entropy_loss": -0.0010595793137326837,
#     "train/grad_norm": 1.2647496461868286,
#     "train/loss": 6.097572326660156,
#     "train/n_updates": 17,
#     "train/policy_gradient_loss": 2.5736083984375,
#     "train/value_loss": 3.5250232219696045
# }
# {'train/entropy_loss': -6.990383827343294e-09, 'train/entropy': 6.990383553784341e-06, 'train/policy_gradient_loss': -0.0, 'train/loss': 62.23827362060547, 'train/grad_norm': 0.0001942136004799977, 'train/n_updates': 23, 'train/baseline': -1.8378124237060547, 'train/value_loss': 62.23827362060547, 'time/iterations': 24, 'rollout/ep_rew_mean': 1267.4490966796875, 'rollout/ep_len_mean': 219.5, 'time/fps': 338, 'time/time_elapsed': 21, 'global_step': 7137, 'num_episodes': 24}
# {
#     "global_step": 7137,
#     "num_episodes": 24,
#     "rollout/ep_len_mean": 219.5,
#     "rollout/ep_rew_mean": 1267.4490966796875,
#     "time/fps": 338,
#     "time/iterations": 24,
#     "time/time_elapsed": 21,
#     "train/baseline": -1.8378124237060547,
#     "train/entropy": 6.990383553784341e-06,
#     "train/entropy_loss": -6.990383827343294e-09,
#     "train/grad_norm": 0.0001942136004799977,
#     "train/loss": 62.23827362060547,
#     "train/n_updates": 23,
#     "train/policy_gradient_loss": -0.0,
#     "train/value_loss": 62.23827362060547
# }
# Решено!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▂▃▅▆▇█</td></tr><tr><td>num_episodes</td><td>▁▂▃▄▅▆█</td></tr><tr><td>rollout/ep_len_mean</td><td>▅█▇▆▄▄▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁▂▃█</td></tr><tr><td>time/fps</td><td>█▁▂▃▄▄▄</td></tr><tr><td>time/iterations</td><td>▁▂▃▄▅▆█</td></tr><tr><td>time/time_elapsed</td><td>▁▃▄▅▆▇█</td></tr><tr><td>train/baseline</td><td>████▆▇▁</td></tr><tr><td>train/entropy</td><td>████▃▅▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▆▄█</td></tr><tr><td>train/grad_norm</td><td>▁▁▁▁▂█▁</td></tr><tr><td>train/loss</td><td>▁▁▁▁▁▂█</td></tr><tr><td>train/n_updates</td><td>▁▂▃▄▅▆█</td></tr><tr><td>train/policy_gradient_loss</td><td>▂▃▁▁▃█▂</td></tr><tr><td>train/value_loss</td><td>▁▁▁▁▁▁█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>7137</td></tr><tr><td>num_episodes</td><td>24</td></tr><tr><td>rollout/ep_len_mean</td><td>219.5</td></tr><tr><td>rollout/ep_rew_mean</td><td>1267.4491</td></tr><tr><td>time/fps</td><td>338</td></tr><tr><td>time/iterations</td><td>24</td></tr><tr><td>time/time_elapsed</td><td>21</td></tr><tr><td>train/baseline</td><td>-1.83781</td></tr><tr><td>train/entropy</td><td>1e-05</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>0.00019</td></tr><tr><td>train/loss</td><td>62.23827</td></tr><tr><td>train/n_updates</td><td>23</td></tr><tr><td>train/policy_gradient_loss</td><td>0</td></tr><tr><td>train/value_loss</td><td>62.23827</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">reinforce_value-baseline</strong> at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/7z4dq9v9' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/7z4dq9v9</a><br> View project at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251101_131932-7z4dq9v9/logs</code>

# %% [markdown]
# # 3 REINFORCE с разбиением на мини-батчи
# В предыдущих реализациях по данным одной собранной траетории стратегия обновлялась только один раз. Попробуем разбить траекторию на мини-батчи и обучаться на одной траектории в течение нескольких эпох. С одной стороны это должно привести к ускорению обучения, поскольку модели будут обновляться чаще. С другой стороны такая схема обучения отходит от on-policy режима.

# %%
class BatchedReturnBuffer(AverageReturnBuffer):
    def __init__(self, gamma: float = 0.99, device: Union[torch.device, str] = "cpu"):
        super().__init__(gamma, device)
        self.generator_ready = None

    def reset(self) -> None:
        super().reset()
        self.generator_ready = False

    def get(self, batch_size: Optional[Union[int, float]] = None) -> Generator[BufferSamples, None, None]:
        buffer_size = self.size()
        indices = np.random.permutation(buffer_size)
        if not self.generator_ready:
            self.observations = np.asarray(self.observations)
            self.actions = np.asarray(self.actions)
            self.returns = np.asarray(self.returns, dtype=np.float32)
            self.generator_ready = True

        if batch_size is None or math.isinf(batch_size):
            batch_size = buffer_size

        start_idx = 0
        while start_idx < buffer_size:
            yield self._get_samples(indices[start_idx: start_idx + batch_size])
            start_idx += batch_size

# %% [markdown]
# (3 балла)

# %%
class BatchedAverageReturnReinforce(Reinforce):
    def __init__(self, env: gym.Env, learning_rate: float = 2.5e-4, gamma: float = 0.99, ent_coef: float = 0.001,
                 max_grad_norm: float = 0.5, stats_window_size: int = 10, policy_class: Type[ReinforcePolicy] = ReinforcePolicy,
                 policy_kwargs: Optional[Dict[str, Any]] = None, buffer_class: Type[BatchedReturnBuffer] = BatchedReturnBuffer,
                 buffer_kwargs: Optional[Dict[str, Any]] = None, seed: Optional[int] = None,
                 device: Union[torch.device, str] = "cuda", batch_size: Union[int, float] = 64, n_epochs: int = 1):
        super().__init__(env, learning_rate, gamma, ent_coef, max_grad_norm, stats_window_size, policy_class, policy_kwargs,
                         buffer_class, buffer_kwargs, seed, device)
        self.batch_size = batch_size
        self.n_epochs = n_epochs

    def train(self) -> None:
        # В train выполняется self.n_epochs проходов по буферу.
        # Данные из буфера сэмплируются батчами размера self.batch_size: self.buffer.get(self.batch_size).
        # Тело функции аналогично методу train в AverageReturnBaselineReinforce,
        # единственное отличие - несколько эпох обучения и обучение на батчах.
        self.policy.set_training_mode(True)
        for _ in range(self.n_epochs):
          entropies = []
          entropy_losses = []
          policy_losses = []
          losses = []
          grad_norms = []
          baselines = []
          for batch in self.buffer.get(self.batch_size):

            rollout_data = batch
            actions = rollout_data.actions.long()
            policy_output = self.policy.evaluate_actions(rollout_data.observations, actions)
            log_prob = policy_output['log_prob']
            entropy = policy_output['entropy']

            # Получаем среднюю отдачу
            baseline = self.buffer.get_average_return()
            returns = rollout_data.returns

            # Посчитать отдачи с учётом базового уровня
            returns = returns - baseline
            # raise NotImplementedError

            # Policy gradient loss
            policy_loss = -(returns * log_prob).mean()

            # Entropy loss
            entropy = torch.mean(entropy)
            entropy_loss = -self.ent_coef * entropy

            loss = policy_loss + entropy_loss

            # Optimization step
            self.policy.optimizer.zero_grad()
            loss.backward()
            grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
            self.policy.optimizer.step()

            self._n_updates += 1

            entropies.append(entropy.item())
            entropy_losses.append(entropy_loss.item())
            policy_losses.append(policy_loss.item())
            losses.append(loss.item())
            grad_norms.append(grad_norm.item())
            baselines.append(baseline)

          self.log_dict = dict([
              ("train/entropy_loss", np.mean(entropy_losses)), ("train/entropy", np.mean(entropies)),
              ("train/policy_gradient_loss", np.mean(policy_losses)), ("train/loss", np.mean(losses)),
              ("train/grad_norm", np.mean(grad_norms)), ("train/n_updates", self._n_updates),
              ("train/baseline", np.mean(baselines))
          ])

# %% [markdown]
# ### Одна эпоха обучения

# %%
run_algorithm(
    algorithm_class=BatchedAverageReturnReinforce,
    algorithm_kwargs=dict(seed=0, batch_size=64, n_epochs=1),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_batch-epoch-1'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                    save_checkpoint_path='/content/drive/My Drive/seminar_actor-critic/reinforce_batch-epoch-1')
)
# Out:
# /usr/local/lib/python3.12/dist-packages/vizdoom/gymnasium_wrapper/base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# Using cuda device
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/content/wandb/run-20251101_132901-la6o0rhy</code>
# Syncing run <strong><a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/la6o0rhy' target="_blank">reinforce_batch-epoch-1</a></strong> to <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a>
#  View run at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/la6o0rhy' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/la6o0rhy</a>
# {'train/entropy_loss': np.float64(-0.0020775262576838336), 'train/entropy': np.float64(2.0775261720021567), 'train/policy_gradient_loss': np.float64(0.011769400288661322), 'train/loss': np.float64(0.009691875350351134), 'train/grad_norm': np.float64(0.05869504250586033), 'train/n_updates': 16, 'train/baseline': np.float64(-0.2779414019328623), 'time/iterations': 4, 'rollout/ep_rew_mean': -61.659122467041016, 'rollout/ep_len_mean': 760.0, 'time/fps': 429, 'time/time_elapsed': 7, 'global_step': 3040, 'num_episodes': 4}
# {
#     "global_step": 3040,
#     "num_episodes": 4,
#     "rollout/ep_len_mean": 760.0,
#     "rollout/ep_rew_mean": -61.659122467041016,
#     "time/fps": 429,
#     "time/iterations": 4,
#     "time/time_elapsed": 7,
#     "train/baseline": -0.2779414019328623,
#     "train/entropy": 2.0775261720021567,
#     "train/entropy_loss": -0.0020775262576838336,
#     "train/grad_norm": 0.05869504250586033,
#     "train/loss": 0.009691875350351134,
#     "train/n_updates": 16,
#     "train/policy_gradient_loss": 0.011769400288661322
# }
# {'train/entropy_loss': np.float64(-0.0020761170960737), 'train/entropy': np.float64(2.07611701705239), 'train/policy_gradient_loss': np.float64(0.1914234021396348), 'train/loss': np.float64(0.1893472843097918), 'train/grad_norm': np.float64(0.05183464841860713), 'train/n_updates': 49, 'train/baseline': np.float64(-0.07143345334194072), 'time/iterations': 5, 'rollout/ep_rew_mean': -59.86366653442383, 'rollout/ep_len_mean': 667.0, 'time/fps': 403, 'time/time_elapsed': 8, 'global_step': 3335, 'num_episodes': 5}
# {
#     "global_step": 3335,
#     "num_episodes": 5,
#     "rollout/ep_len_mean": 667.0,
#     "rollout/ep_rew_mean": -59.86366653442383,
#     "time/fps": 403,
#     "time/iterations": 5,
#     "time/time_elapsed": 8,
#     "train/baseline": -0.07143345334194072,
#     "train/entropy": 2.07611701705239,
#     "train/entropy_loss": -0.0020761170960737,
#     "train/grad_norm": 0.05183464841860713,
#     "train/loss": 0.1893472843097918,
#     "train/n_updates": 49,
#     "train/policy_gradient_loss": 0.1914234021396348
# }
# {'train/entropy_loss': np.float64(-0.0015386749346362194), 'train/entropy': np.float64(1.5386749096214771), 'train/policy_gradient_loss': np.float64(-0.34425188601017), 'train/loss': np.float64(-0.34579055905342104), 'train/grad_norm': np.float64(0.8067222982645035), 'train/n_updates': 54, 'train/baseline': np.float64(-0.08451958063720874), 'time/iterations': 6, 'rollout/ep_rew_mean': 330.0237731933594, 'rollout/ep_len_mean': 585.3333333333334, 'time/fps': 392, 'time/time_elapsed': 8, 'global_step': 3512, 'num_episodes': 6}
# {
#     "global_step": 3512,
#     "num_episodes": 6,
#     "rollout/ep_len_mean": 585.3333333333334,
#     "rollout/ep_rew_mean": 330.0237731933594,
#     "time/fps": 392,
#     "time/iterations": 6,
#     "time/time_elapsed": 8,
#     "train/baseline": -0.08451958063720874,
#     "train/entropy": 1.5386749096214771,
#     "train/entropy_loss": -0.0015386749346362194,
#     "train/grad_norm": 0.8067222982645035,
#     "train/loss": -0.34579055905342104,
#     "train/n_updates": 54,
#     "train/policy_gradient_loss": -0.34425188601017
# }
# {'train/entropy_loss': np.float64(-2.087910067061216e-09), 'train/entropy': np.float64(2.0879098959388407e-06), 'train/policy_gradient_loss': np.float64(0.0), 'train/loss': np.float64(-2.087910067061216e-09), 'train/grad_norm': np.float64(2.34414934917974e-05), 'train/n_updates': 66, 'train/baseline': np.float64(0.9823269746815594), 'time/iterations': 10, 'rollout/ep_rew_mean': 865.1663818359375, 'rollout/ep_len_mean': 414.3, 'time/fps': 393, 'time/time_elapsed': 10, 'global_step': 4143, 'num_episodes': 10}
# {
#     "global_step": 4143,
#     "num_episodes": 10,
#     "rollout/ep_len_mean": 414.3,
#     "rollout/ep_rew_mean": 865.1663818359375,
#     "time/fps": 393,
#     "time/iterations": 10,
#     "time/time_elapsed": 10,
#     "train/baseline": 0.9823269746815594,
#     "train/entropy": 2.0879098959388407e-06,
#     "train/entropy_loss": -2.087910067061216e-09,
#     "train/grad_norm": 2.34414934917974e-05,
#     "train/loss": -2.087910067061216e-09,
#     "train/n_updates": 66,
#     "train/policy_gradient_loss": 0.0
# }
# {'train/entropy_loss': np.float64(-2.0432002756365364e-09), 'train/entropy': np.float64(2.043200159581223e-06), 'train/policy_gradient_loss': np.float64(0.0), 'train/loss': np.float64(-2.0432002756365364e-09), 'train/grad_norm': np.float64(1.838467323977966e-05), 'train/n_updates': 81, 'train/baseline': np.float64(2.406270650239057), 'time/iterations': 15, 'rollout/ep_rew_mean': 2034.881591796875, 'rollout/ep_len_mean': 167.1, 'time/fps': 398, 'time/time_elapsed': 12, 'global_step': 5006, 'num_episodes': 15}
# {
#     "global_step": 5006,
#     "num_episodes": 15,
#     "rollout/ep_len_mean": 167.1,
#     "rollout/ep_rew_mean": 2034.881591796875,
#     "time/fps": 398,
#     "time/iterations": 15,
#     "time/time_elapsed": 12,
#     "train/baseline": 2.406270650239057,
#     "train/entropy": 2.043200159581223e-06,
#     "train/entropy_loss": -2.0432002756365364e-09,
#     "train/grad_norm": 1.838467323977966e-05,
#     "train/loss": -2.0432002756365364e-09,
#     "train/n_updates": 81,
#     "train/policy_gradient_loss": 0.0
# }
# Решено!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▂▃▅█</td></tr><tr><td>num_episodes</td><td>▁▂▂▅█</td></tr><tr><td>rollout/ep_len_mean</td><td>█▇▆▄▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▂▄█</td></tr><tr><td>time/fps</td><td>█▃▁▁▂</td></tr><tr><td>time/iterations</td><td>▁▂▂▅█</td></tr><tr><td>time/time_elapsed</td><td>▁▂▂▅█</td></tr><tr><td>train/baseline</td><td>▁▂▂▄█</td></tr><tr><td>train/entropy</td><td>██▆▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▃██</td></tr><tr><td>train/grad_norm</td><td>▂▁█▁▁</td></tr><tr><td>train/loss</td><td>▆█▁▆▆</td></tr><tr><td>train/n_updates</td><td>▁▅▅▆█</td></tr><tr><td>train/policy_gradient_loss</td><td>▆█▁▅▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>5006</td></tr><tr><td>num_episodes</td><td>15</td></tr><tr><td>rollout/ep_len_mean</td><td>167.1</td></tr><tr><td>rollout/ep_rew_mean</td><td>2034.88159</td></tr><tr><td>time/fps</td><td>398</td></tr><tr><td>time/iterations</td><td>15</td></tr><tr><td>time/time_elapsed</td><td>12</td></tr><tr><td>train/baseline</td><td>2.40627</td></tr><tr><td>train/entropy</td><td>0.0</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>2e-05</td></tr><tr><td>train/loss</td><td>-0.0</td></tr><tr><td>train/n_updates</td><td>81</td></tr><tr><td>train/policy_gradient_loss</td><td>0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">reinforce_batch-epoch-1</strong> at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/la6o0rhy' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/la6o0rhy</a><br> View project at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251101_132901-la6o0rhy/logs</code>

# %% [markdown]
# ### Две эпохи обучения

# %%
run_algorithm(
    algorithm_class=BatchedAverageReturnReinforce,
    algorithm_kwargs=dict(seed=0, batch_size=128, n_epochs=2),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_batch-epoch-2'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                    save_checkpoint_path='/content/drive/My Drive/seminar_actor-critic/reinforce_batch-epoch-2')
)
# Out:
# Using cuda device
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/content/wandb/run-20251101_132940-7k7h5lkn</code>
# Syncing run <strong><a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/7k7h5lkn' target="_blank">reinforce_batch-epoch-2</a></strong> to <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a>
#  View run at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/7k7h5lkn' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/7k7h5lkn</a>
# {'train/entropy_loss': np.float64(-0.0020713103003799915), 'train/entropy': np.float64(2.07131020228068), 'train/policy_gradient_loss': np.float64(0.16770772635936737), 'train/loss': np.float64(0.16563642024993896), 'train/grad_norm': np.float64(0.046543020755052567), 'train/n_updates': 10, 'train/baseline': np.float64(-0.21440497014092416), 'time/iterations': 3, 'rollout/ep_rew_mean': -91.67717742919922, 'rollout/ep_len_mean': 401.3333333333333, 'time/fps': 443, 'time/time_elapsed': 2, 'global_step': 1204, 'num_episodes': 3}
# {
#     "global_step": 1204,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 401.3333333333333,
#     "rollout/ep_rew_mean": -91.67717742919922,
#     "time/fps": 443,
#     "time/iterations": 3,
#     "time/time_elapsed": 2,
#     "train/baseline": -0.21440497014092416,
#     "train/entropy": 2.07131020228068,
#     "train/entropy_loss": -0.0020713103003799915,
#     "train/grad_norm": 0.046543020755052567,
#     "train/loss": 0.16563642024993896,
#     "train/n_updates": 10,
#     "train/policy_gradient_loss": 0.16770772635936737
# }
# {'train/entropy_loss': np.float64(-0.0020357982721179724), 'train/entropy': np.float64(2.035798192024231), 'train/policy_gradient_loss': np.float64(0.20271406322717667), 'train/loss': np.float64(0.2006782665848732), 'train/grad_norm': np.float64(0.17877822369337082), 'train/n_updates': 32, 'train/baseline': np.float64(-0.1875694362702192), 'time/iterations': 6, 'rollout/ep_rew_mean': -37.70671463012695, 'rollout/ep_len_mean': 368.0, 'time/fps': 283, 'time/time_elapsed': 7, 'global_step': 2208, 'num_episodes': 6}
# {
#     "global_step": 2208,
#     "num_episodes": 6,
#     "rollout/ep_len_mean": 368.0,
#     "rollout/ep_rew_mean": -37.70671463012695,
#     "time/fps": 283,
#     "time/iterations": 6,
#     "time/time_elapsed": 7,
#     "train/baseline": -0.1875694362702192,
#     "train/entropy": 2.035798192024231,
#     "train/entropy_loss": -0.0020357982721179724,
#     "train/grad_norm": 0.17877822369337082,
#     "train/loss": 0.2006782665848732,
#     "train/n_updates": 32,
#     "train/policy_gradient_loss": 0.20271406322717667
# }
# {'train/entropy_loss': np.float64(-0.002020342741161585), 'train/entropy': np.float64(2.0203425884246826), 'train/policy_gradient_loss': np.float64(0.5851160883903503), 'train/loss': np.float64(0.5830957492192587), 'train/grad_norm': np.float64(0.17388356973727545), 'train/n_updates': 38, 'train/baseline': np.float64(-0.12770982145567913), 'time/iterations': 7, 'rollout/ep_rew_mean': -30.25809097290039, 'rollout/ep_len_mean': 615.4285714285714, 'time/fps': 341, 'time/time_elapsed': 12, 'global_step': 4308, 'num_episodes': 7}
# {
#     "global_step": 4308,
#     "num_episodes": 7,
#     "rollout/ep_len_mean": 615.4285714285714,
#     "rollout/ep_rew_mean": -30.25809097290039,
#     "time/fps": 341,
#     "time/iterations": 7,
#     "time/time_elapsed": 12,
#     "train/baseline": -0.12770982145567913,
#     "train/entropy": 2.0203425884246826,
#     "train/entropy_loss": -0.002020342741161585,
#     "train/grad_norm": 0.17388356973727545,
#     "train/loss": 0.5830957492192587,
#     "train/n_updates": 38,
#     "train/policy_gradient_loss": 0.5851160883903503
# }
# {'train/entropy_loss': np.float64(-0.002069345921935404), 'train/entropy': np.float64(2.0693458248587215), 'train/policy_gradient_loss': np.float64(0.13583402083638837), 'train/loss': np.float64(0.1337646752705469), 'train/grad_norm': np.float64(0.05908811486819211), 'train/n_updates': 72, 'train/baseline': np.float64(-0.06713996816566226), 'time/iterations': 8, 'rollout/ep_rew_mean': -30.909008026123047, 'rollout/ep_len_mean': 576.5, 'time/fps': 338, 'time/time_elapsed': 13, 'global_step': 4612, 'num_episodes': 8}
# {
#     "global_step": 4612,
#     "num_episodes": 8,
#     "rollout/ep_len_mean": 576.5,
#     "rollout/ep_rew_mean": -30.909008026123047,
#     "time/fps": 338,
#     "time/iterations": 8,
#     "time/time_elapsed": 13,
#     "train/baseline": -0.06713996816566226,
#     "train/entropy": 2.0693458248587215,
#     "train/entropy_loss": -0.002069345921935404,
#     "train/grad_norm": 0.05908811486819211,
#     "train/loss": 0.1337646752705469,
#     "train/n_updates": 72,
#     "train/policy_gradient_loss": 0.13583402083638837
# }
# {'train/entropy_loss': np.float64(-0.002075617201626301), 'train/entropy': np.float64(2.0756170749664307), 'train/policy_gradient_loss': np.float64(-0.40042491753896076), 'train/loss': np.float64(-0.40250054001808167), 'train/grad_norm': np.float64(0.04877870654066404), 'train/n_updates': 84, 'train/baseline': np.float64(-0.08559718855681137), 'time/iterations': 10, 'rollout/ep_rew_mean': -39.57916259765625, 'rollout/ep_len_mean': 532.7, 'time/fps': 348, 'time/time_elapsed': 15, 'global_step': 5327, 'num_episodes': 10}
# {
#     "global_step": 5327,
#     "num_episodes": 10,
#     "rollout/ep_len_mean": 532.7,
#     "rollout/ep_rew_mean": -39.57916259765625,
#     "time/fps": 348,
#     "time/iterations": 10,
#     "time/time_elapsed": 15,
#     "train/baseline": -0.08559718855681137,
#     "train/entropy": 2.0756170749664307,
#     "train/entropy_loss": -0.002075617201626301,
#     "train/grad_norm": 0.04877870654066404,
#     "train/loss": -0.40250054001808167,
#     "train/n_updates": 84,
#     "train/policy_gradient_loss": -0.40042491753896076
# }
# {'train/entropy_loss': np.float64(-0.002076143631711602), 'train/entropy': np.float64(2.076143503189087), 'train/policy_gradient_loss': np.float64(-0.31058236956596375), 'train/loss': np.float64(-0.31265851855278015), 'train/grad_norm': np.float64(0.03603385885556539), 'train/n_updates': 96, 'train/baseline': np.float64(-0.09757590567585923), 'time/iterations': 12, 'rollout/ep_rew_mean': -17.091108322143555, 'rollout/ep_len_mean': 591.8, 'time/fps': 362, 'time/time_elapsed': 18, 'global_step': 6537, 'num_episodes': 12}
# {
#     "global_step": 6537,
#     "num_episodes": 12,
#     "rollout/ep_len_mean": 591.8,
#     "rollout/ep_rew_mean": -17.091108322143555,
#     "time/fps": 362,
#     "time/iterations": 12,
#     "time/time_elapsed": 18,
#     "train/baseline": -0.09757590567585923,
#     "train/entropy": 2.076143503189087,
#     "train/entropy_loss": -0.002076143631711602,
#     "train/grad_norm": 0.03603385885556539,
#     "train/loss": -0.31265851855278015,
#     "train/n_updates": 96,
#     "train/policy_gradient_loss": -0.31058236956596375
# }
# {'train/entropy_loss': np.float64(-0.001239324842269222), 'train/entropy': np.float64(1.2393247683842976), 'train/policy_gradient_loss': np.float64(-0.40574686725934345), 'train/loss': np.float64(-0.40698618690172833), 'train/grad_norm': np.float64(1.6773787041505177), 'train/n_updates': 116, 'train/baseline': np.float64(-0.06597344989024113), 'time/iterations': 14, 'rollout/ep_rew_mean': 223.86544799804688, 'rollout/ep_len_mean': 540.3, 'time/fps': 357, 'time/time_elapsed': 19, 'global_step': 7000, 'num_episodes': 14}
# {
#     "global_step": 7000,
#     "num_episodes": 14,
#     "rollout/ep_len_mean": 540.3,
#     "rollout/ep_rew_mean": 223.86544799804688,
#     "time/fps": 357,
#     "time/iterations": 14,
#     "time/time_elapsed": 19,
#     "train/baseline": -0.06597344989024113,
#     "train/entropy": 1.2393247683842976,
#     "train/entropy_loss": -0.001239324842269222,
#     "train/grad_norm": 1.6773787041505177,
#     "train/loss": -0.40698618690172833,
#     "train/n_updates": 116,
#     "train/policy_gradient_loss": -0.40574686725934345
# }
# {'train/entropy_loss': np.float64(-8.581623478676192e-05), 'train/entropy': np.float64(0.08581622876226902), 'train/policy_gradient_loss': np.float64(0.2493213713169098), 'train/loss': np.float64(0.24923554807901382), 'train/grad_norm': np.float64(1.0739756226539612), 'train/n_updates': 140, 'train/baseline': np.float64(0.6022966035136731), 'time/iterations': 20, 'rollout/ep_rew_mean': 1078.60009765625, 'rollout/ep_len_mean': 269.3, 'time/fps': 352, 'time/time_elapsed': 22, 'global_step': 8020, 'num_episodes': 20}
# {
#     "global_step": 8020,
#     "num_episodes": 20,
#     "rollout/ep_len_mean": 269.3,
#     "rollout/ep_rew_mean": 1078.60009765625,
#     "time/fps": 352,
#     "time/iterations": 20,
#     "time/time_elapsed": 22,
#     "train/baseline": 0.6022966035136731,
#     "train/entropy": 0.08581622876226902,
#     "train/entropy_loss": -8.581623478676192e-05,
#     "train/grad_norm": 1.0739756226539612,
#     "train/loss": 0.24923554807901382,
#     "train/n_updates": 140,
#     "train/policy_gradient_loss": 0.2493213713169098
# }
# {'train/entropy_loss': np.float64(-8.188801814412727e-08), 'train/entropy': np.float64(8.188801439246163e-05), 'train/policy_gradient_loss': np.float64(4.598052873916458e-05), 'train/loss': np.float64(4.5898641474195756e-05), 'train/grad_norm': np.float64(0.006405430845916271), 'train/n_updates': 164, 'train/baseline': np.float64(1.4621811797521616), 'time/iterations': 26, 'rollout/ep_rew_mean': 1752.1781005859375, 'rollout/ep_len_mean': 166.3, 'time/fps': 358, 'time/time_elapsed': 25, 'global_step': 9016, 'num_episodes': 26}
# {
#     "global_step": 9016,
#     "num_episodes": 26,
#     "rollout/ep_len_mean": 166.3,
#     "rollout/ep_rew_mean": 1752.1781005859375,
#     "time/fps": 358,
#     "time/iterations": 26,
#     "time/time_elapsed": 25,
#     "train/baseline": 1.4621811797521616,
#     "train/entropy": 8.188801439246163e-05,
#     "train/entropy_loss": -8.188801814412727e-08,
#     "train/grad_norm": 0.006405430845916271,
#     "train/loss": 4.5898641474195756e-05,
#     "train/n_updates": 164,
#     "train/policy_gradient_loss": 4.598052873916458e-05
# }
# Решено!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▂▄▄▅▆▆▇█</td></tr><tr><td>num_episodes</td><td>▁▂▂▃▃▄▄▆█</td></tr><tr><td>rollout/ep_len_mean</td><td>▅▄█▇▇█▇▃▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁▁▁▂▅█</td></tr><tr><td>time/fps</td><td>█▁▄▃▄▄▄▄▄</td></tr><tr><td>time/iterations</td><td>▁▂▂▃▃▄▄▆█</td></tr><tr><td>time/time_elapsed</td><td>▁▃▄▄▅▆▆▇█</td></tr><tr><td>train/baseline</td><td>▁▁▁▂▂▁▂▄█</td></tr><tr><td>train/entropy</td><td>██████▅▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁▁▄██</td></tr><tr><td>train/grad_norm</td><td>▁▂▂▁▁▁█▅▁</td></tr><tr><td>train/loss</td><td>▅▅█▅▁▂▁▆▄</td></tr><tr><td>train/n_updates</td><td>▁▂▂▄▄▅▆▇█</td></tr><tr><td>train/policy_gradient_loss</td><td>▅▅█▅▁▂▁▆▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>9016</td></tr><tr><td>num_episodes</td><td>26</td></tr><tr><td>rollout/ep_len_mean</td><td>166.3</td></tr><tr><td>rollout/ep_rew_mean</td><td>1752.1781</td></tr><tr><td>time/fps</td><td>358</td></tr><tr><td>time/iterations</td><td>26</td></tr><tr><td>time/time_elapsed</td><td>25</td></tr><tr><td>train/baseline</td><td>1.46218</td></tr><tr><td>train/entropy</td><td>8e-05</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>0.00641</td></tr><tr><td>train/loss</td><td>5e-05</td></tr><tr><td>train/n_updates</td><td>164</td></tr><tr><td>train/policy_gradient_loss</td><td>5e-05</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">reinforce_batch-epoch-2</strong> at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/7k7h5lkn' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/7k7h5lkn</a><br> View project at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251101_132940-7k7h5lkn/logs</code>
